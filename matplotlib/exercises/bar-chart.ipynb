# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %% [markdown]
# #### 1. Write a Python programming to display a bar chart of the popularity of programming Languages.

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]

df = pd.DataFrame({
    'Linguagem': languages,
    'Popularidade (%)': popularity
})

df
# Out:
#     Linguagem  Popularidade (%)
# 0        Java              22.2
# 1      Python              17.6
# 2         PHP               8.8
# 3  JavaScript               8.0
# 4          C#               7.7
# 5         C++               6.7

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))

x = df['Linguagem']
y = df['Popularidade (%)']

ax.bar(x, y, color='blue', edgecolor='black')
ax.set_title('Popularity of Programming Language \nWorldwide, Oct 2017 compared to a year ago', fontsize=14, pad=10)

ax.set_xlabel('Languages', labelpad=20)
ax.set_ylabel('Popularity (%)', labelpad=20)
ax.set_ylim(0, 30)

plt.grid(color='r', linestyle='--', linewidth=0.5)

# %% [markdown]
# #### 2. Write a Python programming to display a horizontal bar chart of the popularity of programming Languages.

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = np.array([22.2, 17.6, 8.8, 8.0, 7.7, 6.7])

df = pd.DataFrame({
    'Linguagem': languages,
    'Popularidade (%)': popularity
})
df.head()
# Out:
#     Linguagem  Popularidade (%)
# 0        Java              22.2
# 1      Python              17.6
# 2         PHP               8.8
# 3  JavaScript               8.0
# 4          C#               7.7

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))

y = df['Linguagem']
x = df['Popularidade (%)']

ax.barh(y, x, color='g', edgecolor='black')

ax.set_title('Popularity of Programming Language \nWorldwide, Oct 2017 compared to a year ago', fontsize=14, pad=10)
ax.set_xlabel('Popularity (%)', labelpad=20)
ax.set_ylabel('Languages', labelpad=20)

ax.set_xticks(range(0, 26, 5))

plt.grid(color='r', linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# #### 3. Write a Python programming to display a bar chart of the popularity of programming Languages.

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]

df = pd.DataFrame({
    'Linguagem': languages,
    'Popularidade (%)': popularity
})

df.tail()
# Out:
#     Linguagem  Popularidade (%)
# 1      Python              17.6
# 2         PHP               8.8
# 3  JavaScript               8.0
# 4          C#               7.7
# 5         C++               6.7

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))

x = df['Linguagem']
y = df['Popularidade (%)']

ax.bar(x, y, color='lightskyblue', edgecolor='black')
ax.set_title('Popularity of Programming Language \nWorldwide, Oct 2017 compared to a year ago', fontsize=14, pad=10)
ax.set_xlabel('Languages', labelpad=20)
ax.set_ylabel('Popularity (%)', labelpad=20)
ax.set_ylim(0,25)
plt.grid(color='r', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# #### 4. Write a Python programming to display a horizontal bar chart of the popularity of programming Languages.

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]

df = pd.DataFrame({
    'Linguagem': languages,
    'Popularidade (%)': popularity
})

df.head()
# Out:
#     Linguagem  Popularidade (%)
# 0        Java              22.2
# 1      Python              17.6
# 2         PHP               8.8
# 3  JavaScript               8.0
# 4          C#               7.7

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))
x = df['Linguagem']
y = df['Popularidade (%)']

bar_colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown']

for i in range(len(df)):
    ax.bar(x[i], y[i], color=bar_colors[i], edgecolor='black', label=x[i])

ax.set_title('Popularity of Programming Language \nWorldwide, Oct 2017 compared to a year ago', fontsize=14, pad=10)
ax.set_xlabel('Languages', labelpad=20, fontfamily='arial', fontsize=12, fontweight='bold')
ax.set_ylabel('Popularity (%)', labelpad=20, fontfamily='cursive', fontsize=12)
ax.set_ylim(0, 25)

handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles, strict=False))
ax.legend(by_label.values(), by_label.keys(), title="Languages", loc="upper right", fontsize=10, title_fontsize=12)

plt.grid(color='g', linestyle='--', linewidth=0.5)
plt.show()


fig.savefig('popularity_languages.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# #### 5. Write a Python programming to display a bar chart of the popularity of programming Languages. Attach a text label above each bar displaying its popularity (float value).

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]

df = pd.DataFrame({
  'languages': languages,
  'popularity': popularity
})

x = df['languages']
y = df['popularity']

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))

fig.suptitle('Popularity of Programming Language\nWorldwide, Oct 2017 compared to a year ago')

bars = ax.bar(x, y, color='darkblue')

ax.bar_label(bars, padding=3)
ax.set_xlabel('Languages', labelpad=30)
ax.set_ylabel('Popularity', labelpad=30)

ax.grid(color='r', lw=0.33)

plt.legend(["Languages"], fontsize="large")

ax.set_yticks([0, 5, 10, 15, 20, 25])


plt.show()

# %% [markdown]
# #### 6. Write a Python programming to display a bar chart of the popularity of programming Languages. Make blue border to each bar.

# %%
plt.style.use('bmh')

languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]

df = pd.DataFrame({
  'languages': languages,
  'popularity': popularity
})

x = df['languages']
y = df['popularity']

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))

ax.set_yticks([0, 5, 10, 15, 20, 25])

ax.bar(x, y, edgecolor='darkblue')
ax.set_title('Popularity of Programming Language\nWorldwide, Oct 2017 compared to a year ago', pad=15)
ax.set_xlabel('Languages', labelpad=15, fontweight='bold', fontsize=14)
ax.set_ylabel('Popularity', labelpad=15, fontweight='bold', fontsize=14)

ax.grid(color='r')

plt.show()

# %% [markdown]
# #### 8. Write a Python programming to display a bar chart of the popularity of programming Languages. Select the width of each bar and their positions.

# %%
plt.style.use('seaborn-v0_8-poster')

languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]

df = pd.DataFrame({
  'languages': languages,
  'popularity': popularity
})

x = df['languages']
y = df['popularity']

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))

ax.bar(x, y, color='darkblue', width=0.4)
ax.set_xlabel('Languages', labelpad=15)
ax.set_ylabel('Popularity', labelpad=15)

ax.set_title('Popularity of Programming Language\nWorldwide, Oct 2017 compared to a year ago', pad=15)

ax.grid(color='r', lw=0.6)

plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# #### 9. Write a Python programming to display a bar chart of the popularity of programming Languages. Increase bottom margin.

# %%
plt.style.use('seaborn-v0_8-talk')

languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8.0, 7.7, 6.7]

df = pd.DataFrame({
  'languages': languages,
  'popularity': popularity
})

x = df['languages']
y = df['popularity']

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))

ax.bar(x, y, color='steelblue', edgecolor='black')
ax.set_title('Popularity of Programming Language\nWorldwide, Oct 2017 compared to a year ago', pad=15)

ax.set_xlabel('Languages', labelpad=18)
ax.set_ylabel('Popularity', labelpad=18)

ax.grid(color='r', lw=0.7)

plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# #### 10. Write a Python program to create bar plot of scores by group and gender. Use multiple X values on the same chart for men and women.

# %%
men = (22, 30, 35, 35, 26)
women = (25, 32, 30, 35, 29)
scores = (0, 10, 20, 30, 40)

df = pd.DataFrame({
  'men': men,
  'women': women
})
df
# Out:
#    men  women
# 0   22     25
# 1   30     32
# 2   35     30
# 3   35     35
# 4   26     29

# %%
plt.style.use('ggplot')
x = np.arange(len(scores))
bar_width = 0.35

fig, ax = plt.subplots(figsize=(12, 6))

bars1 = ax.bar(x - bar_width/2, df['men'], width=bar_width, label='Men', color='g', ec='black')
bars2 = ax.bar(x + bar_width/2, df['women'], width=bar_width, label='Women', color='crimson', ec='black')

ax.set_title('Scores by person', pad=19)
ax.set_xlabel('Person', labelpad=19)
ax.set_ylabel('Scores', labelpad=19)
ax.set_xticks(x)
ax.set_xticklabels(['G1', 'G2', 'G3', 'G4', 'G5'])

ax.legend()
ax.grid(True)

plt.show()

# %% [markdown]
# #### 11. Write a Python program to create bar plot from a DataFrame.

# %%
df = pd.DataFrame({
  'a': [2,4,8,5,7,6],
  'b': [4,2,3,4,2,6],
  'c': [6,4,7,4,7,8],
  'd': [8,2,6,4,8,6],
  'e': [10,2,4,3,3,2]
})

df
# Out:
#    a  b  c  d   e
# 0  2  4  6  8  10
# 1  4  2  4  2   2
# 2  8  3  7  6   4
# 3  5  4  4  4   3
# 4  7  2  7  8   3
# 5  6  6  8  6   2

# %%
bar = df.plot.bar()

plt.minorticks_on()

plt.legend(loc='upper right')
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

plt.show()
